# %%
for i in range(1):
    print("#")
else:
    print("#")
# Out:
# #
# #

# %%
var = 0
while var < 6:
    var += 1
    if var % 2 == 0:
        continue
    print("#")
# Out:
# #
# #
# #

# %%
var = 1
while var < 10:
    print("#")
    var = var << 1
# Out:
# #
# #
# #
# #

# %%
nums = [1, 2, 3]
vals = nums
del vals[1:2]
print(vals)
